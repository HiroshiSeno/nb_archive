# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
from opmap.RawCam import RawCam
from opmap.VmemMap import VmemMap
from opmap.PhaseMap import PhaseMap
from opmap.PhaseVarianceMap import PhaseVarianceMap
from opmap.util import makeMovie

# %%
import subprocess
output_name = '20170809'
folder_name = '20170809-2'

# %% [markdown]
# # IKr増大による影響

# %%
vmem1 = np.zeros([5400])
vmem2 = np.zeros([5400])
vmem3 = np.zeros([5400])
for i in range(5400):
    num = "{0:05d}".format(i+1)
    vmem1[i] = np.load('/mnt/recordings/SimulationResults/20170624-1/%s/v.npy' % num)
    vmem2[i] = np.load('/mnt/recordings/SimulationResults/20170810-1/%s/v.npy' % num)
    vmem3[i] = np.load('/mnt/recordings/SimulationResults/20170809-2/%s/v.npy' % num)

# %%
plt.plot(vmem1, label='IKr x1.0')
plt.plot(vmem2, label='IKr x1.5')
plt.plot(vmem3, label='IKr x2.0')
plt.xlim(5220, 5400)
plt.xticks([5220, 5240, 5260, 5280, 5300, 5320, 5340, 5360, 5380, 5400], [0, 20, 40, 60, 80, 100, 120, 140, 160, 180])
plt.xlabel('Time (ms)', size=15)
plt.ylabel('Membrane Potential (mV)', size=15)
plt.legend(fontsize=15)
plt.savefig('/mnt/recordings/AnalysisResult/Seno/simulation/Mahajan/20170810/compare.png', dpi=300, transparent=True)
